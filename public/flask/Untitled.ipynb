# %%
from flask import Flask, request, jsonify
import cv2
import json
import tensorflow as tf
from tensorflow import keras
import numpy as np
from keras.models import load_model

# %%
test = tf.saved_model.load('e50')

# %%
weights = test.trainable_variables

# %%
weights
# Out:
# ListWrapper([<tf.Variable 'dense/kernel:0' shape=(2560, 256) dtype=float32, numpy=
# array([[-0.31764844,  0.12483428,  0.02785094, ...,  0.08829197,
#         -0.19927919,  0.04480848],
#        [-0.0633495 ,  0.0292174 , -0.07032633, ..., -0.0368265 ,
#         -0.02802699,  0.01830184],
#        [ 0.03556393,  0.12521723, -0.03886586, ...,  0.13900061,
#         -0.04417146,  0.05985892],
#        ...,
#        [-0.02011291,  0.09178156,  0.04465227, ..., -0.05786462,
#         -0.01732849, -0.11757594],
#        [-0.11283877,  0.08086792,  0.11706369, ...,  0.00925065,
#          0.01098653,  0.06225937],
#        [ 0.1265584 ,  0.11011224, -0.07878898, ...,  0.14713621,
#         -0.07937548,  0.02284931]], dtype=float32)>, <tf.Variable 'dense/bias:0' shape=(256,) dtype=float32, numpy=
# array([ 0.0337408 , -0.06026277, -0.03366533, -0.02396495, -0.00321241,
#         0.00473465,  0.02656222, -0.03709342, -0.05400886, -0.05351111,
# ...

# %%
infer.get_weights()
